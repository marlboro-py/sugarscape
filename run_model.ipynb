# %%
import sugarscape

model = sugarscape.SugarscapeG1mt()
model.run_model()
# Out:
# Could not import SolaraViz. If you need it, install with 'pip install --pre mesa[viz]'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import sugarscape
#       3 model = sugarscape.SugarscapeG1mt()
#       4 model.run_model()
#
# File ~/repos/sugarscape/sugarscape.py:4
#       1 import mesa
#       2 import numpy as np
# ----> 4 from agents import Trader
#       5 from utils import geometric_mean, get_trade, flatten
#       6 from mesa.discrete_space import OrthogonalVonNeumannGrid
#
# File ~/repos/sugarscape/agents.py:3
#       1 import math
#       2 from utils import get_distance
# ----> 3 from mesa.discrete_space import CellAgent
#       6 class Trader(CellAgent):
#       7     """
#       8     Trader:
#       9     - has a metabolism of sugar and spice
#      10     - harvest and trade sugar and spice to survive
#      11     """
#
# ...
